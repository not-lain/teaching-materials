# %% [markdown]
# <a href="https://colab.research.google.com/github/hafedh-hichri/teaching-materials/blob/main/data_manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # downloading the data

# %%
# !git clone https://github.com/hafedh-hichri/teaching-materials.git
# Out:
# fatal: destination path 'teaching-materials' already exists and is not an empty directory.

# %% [markdown]
# # loading the dataset

# %%
import pandas as pd

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = pd.read_csv("/content/teaching-materials/datasets/iris.csv")

# %% [markdown]
# # checking the data head

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# # checking the info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # showing all column names

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
# a cleaner way to show the column names is

list(df.columns)
# Out:
# ['sepal.length', 'sepal.width', 'petal.length', 'petal.width', 'variety']

# %% [markdown]
# # select queries

# %% [markdown]
# ## selecting the a single column

# %%
df['variety']
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: object

# %%
df[['variety']]
# Out:
#        variety
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa
# ..         ...
# 145  Virginica
# 146  Virginica
# 147  Virginica
# 148  Virginica
# 149  Virginica
#
# [150 rows x 1 columns]

# %%
df.loc[:,"variety"]
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: object

# %%
df.loc[:,["variety"]]
# Out:
#        variety
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa
# ..         ...
# 145  Virginica
# 146  Virginica
# 147  Virginica
# 148  Virginica
# 149  Virginica
#
# [150 rows x 1 columns]

# %%
df.iloc[:,4]
df.iloc[:,-1]
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: object

# %%
df.iloc[:,[4]]
df.iloc[:,[-1]]
# Out:
#        variety
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa
# ..         ...
# 145  Virginica
# 146  Virginica
# 147  Virginica
# 148  Virginica
# 149  Virginica
#
# [150 rows x 1 columns]

# %% [markdown]
# ## selecting multiple columns

# %%
df[['petal.width', 'variety']]
# Out:
#      petal.width    variety
# 0            0.2     Setosa
# 1            0.2     Setosa
# 2            0.2     Setosa
# 3            0.2     Setosa
# 4            0.2     Setosa
# ..           ...        ...
# 145          2.3  Virginica
# 146          1.9  Virginica
# 147          2.0  Virginica
# 148          2.3  Virginica
# 149          1.8  Virginica
#
# [150 rows x 2 columns]

# %%
df.loc[:,['petal.width', 'variety']]
# Out:
#      petal.width    variety
# 0            0.2     Setosa
# 1            0.2     Setosa
# 2            0.2     Setosa
# 3            0.2     Setosa
# 4            0.2     Setosa
# ..           ...        ...
# 145          2.3  Virginica
# 146          1.9  Virginica
# 147          2.0  Virginica
# 148          2.3  Virginica
# 149          1.8  Virginica
#
# [150 rows x 2 columns]

# %%
df.iloc[:,[3,4]]
df.iloc[:,3:]
# Out:
#      petal.width    variety
# 0            0.2     Setosa
# 1            0.2     Setosa
# 2            0.2     Setosa
# 3            0.2     Setosa
# 4            0.2     Setosa
# ..           ...        ...
# 145          2.3  Virginica
# 146          1.9  Virginica
# 147          2.0  Virginica
# 148          2.3  Virginica
# 149          1.8  Virginica
#
# [150 rows x 2 columns]

# %% [markdown]
# ## selecting a line

# %%
df.loc[0,:]
df.iloc[0 , : ]
# Out:
# sepal.length       5.1
# sepal.width        3.5
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 0, dtype: object

# %% [markdown]
# ## selecting multiple lines

# %%
# df.loc[[0,1,3] , :]
df.iloc[[0,1,3] , :]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa

# %% [markdown]
# ## selecting lines with a condition

# %%
#df[df["sepal.length"]==5.1]
df.loc[df["sepal.length"]==5.1,:]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width     variety
# 0            5.1          3.5           1.4          0.2      Setosa
# 17           5.1          3.5           1.4          0.3      Setosa
# 19           5.1          3.8           1.5          0.3      Setosa
# 21           5.1          3.7           1.5          0.4      Setosa
# 23           5.1          3.3           1.7          0.5      Setosa
# 39           5.1          3.4           1.5          0.2      Setosa
# 44           5.1          3.8           1.9          0.4      Setosa
# 46           5.1          3.8           1.6          0.2      Setosa
# 98           5.1          2.5           3.0          1.1  Versicolor

# %% [markdown]
# # checking for missing values

# %%
df.isna().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %% [markdown]
# # checking unique values

# %%
df['variety'].nunique()
# Out:
# 3

# %%
df['variety'].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
df['variety'].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %% [markdown]
# # data visualisation

# %%
df["sepal.length"].value_counts().plot(kind="box")

# %%
df["sepal.length"].value_counts().plot(kind="bar")

# %%
df["variety"].value_counts().plot(kind="pie", autopct='%1.0f%%')

# %% [markdown]
# # dropping a column

# %%
df.drop(["variety"],axis=1)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# * DID NOT SAVE AFTER DELETING !!
#
# to fix this uncomment the next cell

# %%
# df = df.drop(["variety"],axis=1) 
# df.drop(["variety"],axis=1, inplace = True )

# %% [markdown]
# # **CREATING X AND Y**

# %%
# reminder this is what our data looks like 
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# creating y 
y = df[['variety']]
y.head()
# Out:
#   variety
# 0  Setosa
# 1  Setosa
# 2  Setosa
# 3  Setosa
# 4  Setosa

# %%
X = df.iloc[:, :-1 ]
X.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
